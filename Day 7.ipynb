# %%
x = input().split()
x
# Out:
# fwft (72) -> ktlj, cntj, xhth
# ['fwft', '(72)', '->', 'ktlj,', 'cntj,', 'xhth']

# %%
for i in range(3,len(x)):
    y.append(x[i])
print(y)
# Out:
# ['ktlj,', 'cntj,', 'xhth', 'ktlj,', 'cntj,', 'xhth']

# %%
left = []
weight = []
right = []
with open('D7 text.txt','r') as file:
    for line in file:
        print(line)
        x = line.split()
        left.append(x[0])
        weight.append(x[1])
        if len(x)>2:
            for i in range(3,len(x)):
                right.append(x[i])

print(left)
print(weight)
print(right)
# Out:
# uglvj (99) -> ymfjt, gkpgf
#
# vvwrg (51)
#
# qrpgt (5)
#
# qhqbqj (55)
#
# taxdaf (23)
#
# zbbdyc (81)
#
# xhymdo (185) -> errip, lsppdni, mxukll
#
# qlrcubm (81)
#
# ukgzz (7)
#
# ubvvr (288) -> hrpzu, msjeeks, ozizlok
#
# zfotzg (45) -> ovomgd, mqhwlq
#
# khdgj (49)
#
# idjugav (99)
#
# heuuqx (77)
#
# yierd (96) -> ubnxkza, whlsvf, pnnpym, tznsg
#
# yciccp (173) -> ijpsv, fjtafl, lxwntcm, saacvs
#
# jcekn (38)
#
# boxtod (126) -> sxtbzfe, etdah
#
# iunue (25)
#
# iceaj (216) -> zbqgiy, taxdaf
#
# vobnuq (64)
#
# grkyj (7)
#
# etgjaum (61)
#
# erjcx (47)
#
# sqcodst (19)
#
# vimzk (67)
#
# gldkli (29)
#
# yikzq (164) -> yhrnh, yipnm
#
# aqksi (155) -> olotqeb, vioyx
#
# wkjhmcd (33)
#
# awsdwry (14)
#
# dgehtvc (191) -> sxwcr, usfkacz
#
# ohprzku (5)
#
# aztstf (32)
#
# grrbzan (61)
#
# spcyi (23)
#
# olntlo (299)
#
# qczgjc (26)
#
# svdlp (11)
#
# ormhqr (83)
#
# wfnox (15)
#
# hqwdr (19)
#
# cwoyko (138) -> uycwnb, pttvms, ingae, tedoj
#
# dgeseao (64)
#
# ...

# %%
left
# Out:
# ['uglvj',
#  'vvwrg',
#  'qrpgt',
#  'qhqbqj',
#  'taxdaf',
#  'zbbdyc',
#  'xhymdo',
#  'qlrcubm',
#  'ukgzz',
#  'ubvvr',
#  'zfotzg',
#  'khdgj',
#  'idjugav',
#  'heuuqx',
#  'yierd',
#  'yciccp',
#  'jcekn',
#  'boxtod',
#  'iunue',
#  'iceaj',
#  'vobnuq',
#  'grkyj',
#  'etgjaum',
#  'erjcx',
#  'sqcodst',
#  'vimzk',
#  'gldkli',
#  'yikzq',
#  'aqksi',
#  'wkjhmcd',
#  'awsdwry',
#  'dgehtvc',
#  'ohprzku',
#  'aztstf',
#  'grrbzan',
#  'spcyi',
#  'olntlo',
#  'qczgjc',
#  'svdlp',
#  'ormhqr',
#  'wfnox',
#  'hqwdr',
#  'cwoyko',
#  'dgeseao',
#  'iejyzgu',
#  'eqxumuo',
#  'vqpkne',
#  'gmpoe',
#  'yhxkh',
#  'ugeudg',
#  'wfuoll',
#  'xmbafj',
#  'xvpopw',
#  'tcawlkc',
#  'nddekdg',
#  'jtejd',
#  'vyybi',
#  'arhlwh',
#  'ffizjl',
#  'bmwankt',
#  'viantn',
#  'qnqwt',
#  'pcpcm',
#  'orpzr',
#  'ttfdct',
#  'xjsyk',
#  'wiqpx',
#  'pfyexc',
#  'rhifo',
#  'lerqv',
#  'pohqjzd',
#  'scqhs',
#  'vcgyi',
#  'whlsvf',
#  'edyfj',
#  'jpvyg',
#  'jjwadjm',
#  'lomvf',
# ...

# %%
weight
# Out:
# ['(99)',
#  '(51)',
#  '(5)',
#  '(55)',
#  '(23)',
#  '(81)',
#  '(185)',
#  '(81)',
#  '(7)',
#  '(288)',
#  '(45)',
#  '(49)',
#  '(99)',
#  '(77)',
#  '(96)',
#  '(173)',
#  '(38)',
#  '(126)',
#  '(25)',
#  '(216)',
#  '(64)',
#  '(7)',
#  '(61)',
#  '(47)',
#  '(19)',
#  '(67)',
#  '(29)',
#  '(164)',
#  '(155)',
#  '(33)',
#  '(14)',
#  '(191)',
#  '(5)',
#  '(32)',
#  '(61)',
#  '(23)',
#  '(299)',
#  '(26)',
#  '(11)',
#  '(83)',
#  '(15)',
#  '(19)',
#  '(138)',
#  '(64)',
#  '(97)',
#  '(44)',
#  '(11)',
#  '(164)',
#  '(185)',
#  '(68)',
#  '(1715)',
#  '(44)',
#  '(58)',
#  '(38)',
#  '(57)',
#  '(16)',
#  '(86)',
#  '(90)',
#  '(84)',
#  '(71)',
#  '(67)',
#  '(14)',
#  '(36)',
#  '(57)',
#  '(37)',
#  '(217)',
#  '(75)',
#  '(252)',
#  '(66)',
#  '(68)',
#  '(103)',
#  '(61)',
#  '(391)',
#  '(40)',
#  '(85)',
#  '(82)',
#  '(32)',
#  '(40)',
#  '(148)',
#  '(85)',
#  '(24)',
#  '(57)',
#  '(10)',
#  '(45)',
#  '(82)',
#  '(69)',
#  '(12)',
#  '(185)',
#  '(7)',
# ...

# %%
right
# Out:
# ['ymfjt,',
#  'gkpgf',
#  'errip,',
#  'lsppdni,',
#  'mxukll',
#  'hrpzu,',
#  'msjeeks,',
#  'ozizlok',
#  'ovomgd,',
#  'mqhwlq',
#  'ubnxkza,',
#  'whlsvf,',
#  'pnnpym,',
#  'tznsg',
#  'ijpsv,',
#  'fjtafl,',
#  'lxwntcm,',
#  'saacvs',
#  'sxtbzfe,',
#  'etdah',
#  'zbqgiy,',
#  'taxdaf',
#  'yhrnh,',
#  'yipnm',
#  'olotqeb,',
#  'vioyx',
#  'sxwcr,',
#  'usfkacz',
#  'uycwnb,',
#  'pttvms,',
#  'ingae,',
#  'tedoj',
#  'lgnfrti,',
#  'lomvf',
#  'gpxhd,',
#  'deylq',
#  'vyabn,',
#  'xtwaov',
#  'dxffsoq,',
#  'nyzvofv,',
#  'tvrosaa,',
#  'nmojt',
#  'cciwzc,',
#  'qpafkjx,',
#  'axlitg',
#  'wkhzk,',
#  'zlnks',
#  'fzklxq,',
#  'jrbqu,',
#  'qhxns,',
#  'lerqv',
#  'szeszcp,',
#  'wgmvio',
#  'tdmok,',
#  'ygkwtl,',
#  'sgose,',
#  'uohurz',
#  'zhjzpaa,',
#  'qylvdk',
#  'zzqjykw,',
#  'alflnz',
#  'qltdz,',
#  'ppzlmxg',
#  'lhbmgxc,',
#  'qtxkvx,',
#  'kynyas,',
#  'easamud',
#  'ypufgmt,',
#  'qvtwlq',
#  'alywuv,',
#  'nvdoenr,',
#  'mnyng,',
#  'rhsztrd',
# ...

# %%
import re

# %%
r2=[]
for word in right:
     r2.append(word.partition(',')[0])
r2
# Out:
# ['ymfjt',
#  'gkpgf',
#  'errip',
#  'lsppdni',
#  'mxukll',
#  'hrpzu',
#  'msjeeks',
#  'ozizlok',
#  'ovomgd',
#  'mqhwlq',
#  'ubnxkza',
#  'whlsvf',
#  'pnnpym',
#  'tznsg',
#  'ijpsv',
#  'fjtafl',
#  'lxwntcm',
#  'saacvs',
#  'sxtbzfe',
#  'etdah',
#  'zbqgiy',
#  'taxdaf',
#  'yhrnh',
#  'yipnm',
#  'olotqeb',
#  'vioyx',
#  'sxwcr',
#  'usfkacz',
#  'uycwnb',
#  'pttvms',
#  'ingae',
#  'tedoj',
#  'lgnfrti',
#  'lomvf',
#  'gpxhd',
#  'deylq',
#  'vyabn',
#  'xtwaov',
#  'dxffsoq',
#  'nyzvofv',
#  'tvrosaa',
#  'nmojt',
#  'cciwzc',
#  'qpafkjx',
#  'axlitg',
#  'wkhzk',
#  'zlnks',
#  'fzklxq',
#  'jrbqu',
#  'qhxns',
#  'lerqv',
#  'szeszcp',
#  'wgmvio',
#  'tdmok',
#  'ygkwtl',
#  'sgose',
#  'uohurz',
#  'zhjzpaa',
#  'qylvdk',
#  'zzqjykw',
#  'alflnz',
#  'qltdz',
#  'ppzlmxg',
#  'lhbmgxc',
#  'qtxkvx',
#  'kynyas',
#  'easamud',
#  'ypufgmt',
#  'qvtwlq',
#  'alywuv',
#  'nvdoenr',
#  'mnyng',
#  'rhsztrd',
#  'fcmnfq',
#  'nrzhlvo',
#  'vzpkp',
#  'wmfydk',
# ...

# %%
for w in left:
    if w not in r2:
        print(w)
# Out:
# dgoocsw

# %%
weights = {}
with open('D7 text.txt','r') as file:
    for line in file:
        x=line.split()
        weights[x[0]]=int(re.findall('\d+',x[1])[0])
weights
# Out:
# {'uglvj': 99,
#  'vvwrg': 51,
#  'qrpgt': 5,
#  'qhqbqj': 55,
#  'taxdaf': 23,
#  'zbbdyc': 81,
#  'xhymdo': 185,
#  'qlrcubm': 81,
#  'ukgzz': 7,
#  'ubvvr': 288,
#  'zfotzg': 45,
#  'khdgj': 49,
#  'idjugav': 99,
#  'heuuqx': 77,
#  'yierd': 96,
#  'yciccp': 173,
#  'jcekn': 38,
#  'boxtod': 126,
#  'iunue': 25,
#  'iceaj': 216,
#  'vobnuq': 64,
#  'grkyj': 7,
#  'etgjaum': 61,
#  'erjcx': 47,
#  'sqcodst': 19,
#  'vimzk': 67,
#  'gldkli': 29,
#  'yikzq': 164,
#  'aqksi': 155,
#  'wkjhmcd': 33,
#  'awsdwry': 14,
#  'dgehtvc': 191,
#  'ohprzku': 5,
#  'aztstf': 32,
#  'grrbzan': 61,
#  'spcyi': 23,
#  'olntlo': 299,
#  'qczgjc': 26,
#  'svdlp': 11,
#  'ormhqr': 83,
#  'wfnox': 15,
#  'hqwdr': 19,
#  'cwoyko': 138,
#  'dgeseao': 64,
#  'iejyzgu': 97,
#  'eqxumuo': 44,
#  'vqpkne': 11,
#  'gmpoe': 164,
#  'yhxkh': 185,
#  'ugeudg': 68,
#  'wfuoll': 1715,
#  'xmbafj': 44,
#  'xvpopw': 58,
#  'tcawlkc': 38,
#  'nddekdg': 57,
#  'jtejd': 16,
#  'vyybi': 86,
#  'arhlwh': 90,
# ...

# %%
struc = {}
with open('D7 text.txt','r') as file:
    for line in file:
        x = line.split()
        if len(x)>2:
            struc[x[0]]=[x[el].partition(',')[0] for el in range(3,len(x))]
struc
# Out:
# {'abmlupq': ['fcpejj', 'qgiijpu', 'iolil', 'khdgj'],
#  'adwzzi': ['yirmii', 'pptok', 'iqcjr', 'uhuieb'],
#  'aezwvo': ['ayvcc', 'kxsweg'],
#  'afjqx': ['unokgle', 'bwsvr'],
#  'ahuboc': ['jkszke', 'lpxleg'],
#  'aikmwxj': ['bkomu', 'pcmimkt'],
#  'alywuv': ['mlhga',
#   'odzzie',
#   'awddb',
#   'koxzwq',
#   'cczfm',
#   'hipirzc',
#   'qqktjg'],
#  'aonrg': ['fyqlzxt', 'ehhlvc', 'bpzwq', 'qeoicwx'],
#  'aqksi': ['olotqeb', 'vioyx'],
#  'arjsnz': ['rwrusdg', 'krgdzw', 'olhbx'],
#  'atkstsn': ['kntyjf', 'hwcwcn'],
#  'auzdz': ['fiehsiq', 'eylfls', 'cvkec', 'omkgoai'],
#  'avzxg': ['pkeua', 'ubxume'],
#  'awddb': ['npsuo', 'rrrxeic', 'fhyfd'],
#  'awpyosw': ['smbaw', 'xieqyy', 'tbute', 'fwkxcq'],
#  'axlitg': ['imeyrl', 'waoiyzo', 'hqmxuv', 'spcyi'],
#  'bajtat': ['wsqlsgl', 'ykohs'],
#  'bbeclr': ['zwqgf', 'wnmbn', 'jipgo'],
#  'bcjpkwf': ['auulu', 'eeqoiz', 'nmmxms'],
#  'bhtwp': ['scqhs', 'sixicw', 'mgghj'],
#  'bijhyzu': ['jdvfkii', 'chpjfv', 'wgnoil', 'gkgka'],
# ...
